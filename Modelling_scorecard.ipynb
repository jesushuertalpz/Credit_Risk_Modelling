# %%
#We need to install the scorecardpy package to use it in our project.
# This can be done in the terminal (cmd or PowerShell) outside of Python.
# !pip install scorecardpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import scorecardpy as sc

# %%
df = pd.read_csv(r'C:\\Users\\jesus\\Desktop\\Credit Risk Modelling\\credit_risk.csv')

# %%
df.head()  # Display the first few rows of the DataFrame to verify the data
# Out:
#    Age     Sex         Job Housing Saving accounts Checking account  \
# 0   20  female  management     own             NaN         moderate
# 1   60  female     skilled    rent          little           little
# 2   28    male     skilled    free      quite rich              NaN
# 3   54    male   unskilled    free      quite rich              NaN
# 4   47    male  management     own        moderate           little
#
#    Credit amount  Duration              Purpose  Risk
# 0          11766        70  domestic appliances  good
# 1          13098        41  domestic appliances   bad
# 2           5203        65             vacation   bad
# 3          18642        47             vacation   bad
# 4           1038        45                  car   bad

# %%
# We need to define the dependent variable. In this case, the 'risk' column.
y ='Risk'

# %%
bins = sc.woebin(df,y)
# Out:
# [INFO] creating woe binning ...
# C:\Users\jesus\AppData\Roaming\Python\Python312\site-packages\scorecardpy\condition_fun.py:141: UserWarning: The positive value in "Risk" was replaced by 1 and negative value by 0.
#   warnings.warn("The positive value in \"{}\" was replaced by 1 and negative value by 0.".format(y))
# C:\Users\jesus\AppData\Roaming\Python\Python312\site-packages\scorecardpy\condition_fun.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   datetime_cols = dat.apply(pd.to_numeric,errors='ignore').select_dtypes(object).apply(pd.to_datetime,errors='ignore').select_dtypes('datetime64').columns.tolist()
# ...

# %%
sc.woebin_plot(bins)
# Out:
# {'Purpose': <Figure size 640x480 with 2 Axes>,
#  'Checking account': <Figure size 640x480 with 2 Axes>,
#  'Credit amount': <Figure size 640x480 with 2 Axes>,
#  'Housing': <Figure size 640x480 with 2 Axes>,
#  'Sex': <Figure size 640x480 with 2 Axes>,
#  'Duration': <Figure size 640x480 with 2 Axes>,
#  'Job': <Figure size 640x480 with 2 Axes>,
#  'Age': <Figure size 640x480 with 2 Axes>,
#  'Saving accounts': <Figure size 640x480 with 2 Axes>}

# %%
# Values are not representative, hence we need to use a logic dataset
df_2 = pd.read_csv(r'C:\\Users\\jesus\\Desktop\\Credit Risk Modelling\\german_credit_data.csv', index_col=0) # index_col=0 to avoid the first column being treated as a separate column 
df_2.head()  # Display the first few rows of the DataFrame to verify the data
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
y = 'Risk'  # Define the dependent variable for the new dataset

# %%
bins_2 = sc.woebin(df_2, y)
# Out:
# [INFO] creating woe binning ...
# C:\Users\jesus\AppData\Roaming\Python\Python312\site-packages\scorecardpy\condition_fun.py:141: UserWarning: The positive value in "Risk" was replaced by 1 and negative value by 0.
#   warnings.warn("The positive value in \"{}\" was replaced by 1 and negative value by 0.".format(y))
# C:\Users\jesus\AppData\Roaming\Python\Python312\site-packages\scorecardpy\condition_fun.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   datetime_cols = dat.apply(pd.to_numeric,errors='ignore').select_dtypes(object).apply(pd.to_datetime,errors='ignore').select_dtypes('datetime64').columns.tolist()
# ...

# %%
sc.woebin_plot(bins_2)  # Plot the WOE bins for the new dataset
# Out:
# {'Purpose': <Figure size 640x480 with 2 Axes>,
#  'Checking account': <Figure size 640x480 with 2 Axes>,
#  'Credit amount': <Figure size 640x480 with 2 Axes>,
#  'Housing': <Figure size 640x480 with 2 Axes>,
#  'Sex': <Figure size 640x480 with 2 Axes>,
#  'Duration': <Figure size 640x480 with 2 Axes>,
#  'Job': <Figure size 640x480 with 2 Axes>,
#  'Age': <Figure size 640x480 with 2 Axes>,
#  'Saving accounts': <Figure size 640x480 with 2 Axes>}
